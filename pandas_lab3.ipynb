# %% [markdown]
# <a href="https://colab.research.google.com/github/NIKITACHOKHARIYA/Cricknight/blob/main/pandas_lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pandas Datatype:1.sereies
 # 2.Datafreame :-multidim array in row & column'''
import pandas as pd
f1=pd.read_csv("/content/student.csv")

# %%
print(f1)
# Out:
#     Enrollment_no      Name  Python  Java  Flutter
# 0         2023001    Nikita    85.0  77.0     12.0
# 1         2023002     Viraj    56.0  55.0     12.0
# 2         2023003     Ishan    84.0   NaN     45.0
# 3         2023004   parthiv    63.0   NaN     63.0
# 4         2023005  Riddhesh    85.0  55.0     33.0
# 5         2023006      Parv     NaN  41.0     55.0
# 6         2023007     Divay    85.0  41.0     11.0
# 7         2023008    Nisarg    75.0  22.0     22.0
# 8         2023009    karina    45.0  52.0     45.0
# 9         2023010    Sumeet    45.0  12.0     23.0
# 10        2023011   preksha    56.0  44.0     45.0
# 11        2023012     Rahul    38.0  88.0     75.0
# 12        2023013     Hetal     NaN  75.0     41.0
# 13        2023014    Jishan    66.0  84.0     12.0
# 14        2023015    Raghav    36.0  96.0      NaN
# 15        2023016    Prisha     NaN  78.0      NaN
# 16        2023017     shlok    32.0  45.0     47.0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0a92251ac14c> in <cell line: 1>()
# ----> 1 import matplotlip as mp
#
# ModuleNotFoundError: No module named 'matplotlip'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
f1.head() #top value from file
# Out:
#    Enrollment_no      Name  Python  Java  Flutter
# 0        2023001    Nikita    85.0  77.0     12.0
# 1        2023002     Viraj    56.0  55.0     12.0
# 2        2023003     Ishan    84.0   NaN     45.0
# 3        2023004   parthiv    63.0   NaN     63.0
# 4        2023005  Riddhesh    85.0  55.0     33.0

# %%
f1.tail() # last value from file
# Out:
#     Enrollment_no     Name  Python  Java  Flutter
# 19        2023020    Nidhi    23.0  45.0     11.0
# 20        2023019  darshil    52.0  23.0     11.0
# 21        2023020    Nidhi    23.0  45.0     11.0
# 22        2023012    Rahul    38.0  88.0     75.0
# 23        2023013    Hetal     NaN  75.0     41.0

# %%
f1.describe() #static value information
# Out:
#        Enrollment_no     Python       Java    Flutter
# count   2.400000e+01  20.000000  21.000000  21.000000
# mean    2.023011e+06  54.150000  55.428571  33.380952
# std     5.955755e+00  20.479194  24.816469  21.941915
# min     2.023001e+06  23.000000  12.000000  11.000000
# 25%     2.023007e+06  38.000000  41.000000  12.000000
# 50%     2.023012e+06  52.000000  52.000000  33.000000
# 75%     2.023016e+06  68.250000  77.000000  45.000000
# max     2.023020e+06  85.000000  96.000000  75.000000

# %%
f1.info() #information about the file
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Enrollment_no  24 non-null     int64
#  1   Name           24 non-null     object
#  2   Python         20 non-null     float64
#  3   Java           21 non-null     float64
#  4   Flutter        21 non-null     float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 1.1+ KB

# %%
f1.shape #give Row and column (r,c)
# Out:
# (24, 5)

# %%
f1.iloc[4:8]
# Out:
#    Enrollment_no      Name  Python  Java  Flutter
# 4        2023005  Riddhesh    85.0  55.0     33.0
# 5        2023006      Parv     NaN  41.0     55.0
# 6        2023007     Divay    85.0  41.0     11.0
# 7        2023008    Nisarg    75.0  22.0     22.0

# %%
f1.loc[9:11]
# Out:
#     Enrollment_no     Name  Python  Java  Flutter
# 9         2023010   Sumeet    45.0  12.0     23.0
# 10        2023011  preksha    56.0  44.0     45.0
# 11        2023012    Rahul    38.0  88.0     75.0

# %%
f1.isnull()
# Out:
#     Enrollment_no   Name  Python   Java  Flutter
# 0           False  False   False  False    False
# 1           False  False   False  False    False
# 2           False  False   False   True    False
# 3           False  False   False   True    False
# 4           False  False   False  False    False
# 5           False  False    True  False    False
# 6           False  False   False  False    False
# 7           False  False   False  False    False
# 8           False  False   False  False    False
# 9           False  False   False  False    False
# 10          False  False   False  False    False
# 11          False  False   False  False    False
# 12          False  False    True  False    False
# 13          False  False   False  False    False
# 14          False  False   False  False     True
# 15          False  False    True  False     True
# 16          False  False   False  False    False
# 17          False  False   False   True     True
# ...

# %%
f1.notnull()
# Out:
#     Enrollment_no  Name  Python   Java  Flutter
# 0            True  True    True   True     True
# 1            True  True    True   True     True
# 2            True  True    True  False     True
# 3            True  True    True  False     True
# 4            True  True    True   True     True
# 5            True  True   False   True     True
# 6            True  True    True   True     True
# 7            True  True    True   True     True
# 8            True  True    True   True     True
# 9            True  True    True   True     True
# 10           True  True    True   True     True
# 11           True  True    True   True     True
# 12           True  True   False   True     True
# 13           True  True    True   True     True
# 14           True  True    True   True    False
# 15           True  True   False   True    False
# 16           True  True    True   True     True
# 17           True  True    True  False    False
# 18           True  True    True   True     True
# ...

# %%
f1.drop_duplicates() #remove duplicate  value
# Out:
#     Enrollment_no      Name  Python  Java  Flutter
# 0         2023001    Nikita    85.0  77.0     12.0
# 1         2023002     Viraj    56.0  55.0     12.0
# 2         2023003     Ishan    84.0   NaN     45.0
# 3         2023004   parthiv    63.0   NaN     63.0
# 4         2023005  Riddhesh    85.0  55.0     33.0
# 5         2023006      Parv     NaN  41.0     55.0
# 6         2023007     Divay    85.0  41.0     11.0
# 7         2023008    Nisarg    75.0  22.0     22.0
# 8         2023009    karina    45.0  52.0     45.0
# 9         2023010    Sumeet    45.0  12.0     23.0
# 10        2023011   preksha    56.0  44.0     45.0
# 11        2023012     Rahul    38.0  88.0     75.0
# 12        2023013     Hetal     NaN  75.0     41.0
# 13        2023014    Jishan    66.0  84.0     12.0
# 14        2023015    Raghav    36.0  96.0      NaN
# 15        2023016    Prisha     NaN  78.0      NaN
# 16        2023017     shlok    32.0  45.0     47.0
# ...

# %%
f1.columns # given column name
# Out:
# Index(['Enrollment_no', 'Name', 'Python', 'Java', 'Flutter'], dtype='object')

# %%
f1[['Name','Python']] #given pecific column
# Out:
#         Name  Python
# 0     Nikita    85.0
# 1      Viraj    56.0
# 2      Ishan    84.0
# 3    parthiv    63.0
# 4   Riddhesh    85.0
# 5       Parv     NaN
# 6      Divay    85.0
# 7     Nisarg    75.0
# 8     karina    45.0
# 9     Sumeet    45.0
# 10   preksha    56.0
# 11     Rahul    38.0
# 12     Hetal     NaN
# 13    Jishan    66.0
# 14    Raghav    36.0
# 15    Prisha     NaN
# 16     shlok    32.0
# 17     vivan    44.0
# 18   darshil    52.0
# 19     Nidhi    23.0
# 20   darshil    52.0
# 21     Nidhi    23.0
# 22     Rahul    38.0
# 23     Hetal     NaN

# %%
f1['Python'].value_counts() #category
# Out:
# 85.0    3
# 56.0    2
# 45.0    2
# 38.0    2
# 52.0    2
# 23.0    2
# 84.0    1
# 63.0    1
# 75.0    1
# 66.0    1
# 36.0    1
# 32.0    1
# 44.0    1
# Name: Python, dtype: int64

# %%
f1[f1["Java"]>90]
# Out:
#     Enrollment_no    Name  Python  Java  Flutter
# 14        2023015  Raghav    36.0  96.0      NaN

# %%
f2=pd.read_csv('/content/employees.csv')
f2
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
f2.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
f2.tail()
# Out:
#     First Name Gender  Start Date Last Login Time  Salary  Bonus %  \
# 995      Henry    NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip   Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell   Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry   Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert   Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales

# %%
f2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
f2.describe()
# Out:
#               Salary      Bonus %
# count    1000.000000  1000.000000
# mean    90662.181000    10.207555
# std     32923.693342     5.528481
# min     35013.000000     1.015000
# 25%     62613.000000     5.401750
# 50%     90428.000000     9.838500
# 75%    118740.250000    14.838000
# max    149908.000000    19.944000

# %%
f2['Gender'].value_counts()
# Out:
# Female    431
# Male      424
# Name: Gender, dtype: int64

# %%
f2[f2["Salary"]>147000]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 83       Shawn    Male   9/23/2005         2:55 AM  148115    6.539
# 110    Shirley  Female   6/20/2001        10:39 PM  147113   16.135
# 160      Kathy  Female   3/18/2000         7:26 PM  149563   16.991
# 186        NaN  Female   2/23/2005         9:50 PM  149654    1.825
# 232    Marilyn  Female    4/4/1997         9:28 PM  147663   10.263
# 287       Lois  Female   11/9/2011         7:06 AM  147183    9.999
# 318        Roy    Male    8/6/2006         7:52 AM  148225    1.841
# 368    Marilyn  Female  12/17/1982        12:10 PM  147183    8.748
# 429       Rose  Female   5/28/2015         8:40 AM  149903    5.630
# 471     Sharon  Female   3/12/2002         6:32 AM  147635   14.693
# 541       Ruby  Female    5/1/1999         3:36 AM  147362    7.851
# 628        NaN     NaN    9/2/1988        12:49 PM  147309    1.702
# 644  Katherine  Female   8/13/1996        12:21 AM  149908   18.912
# ...

# %%
f2.isnull()
# Out:
#      First Name  Gender  Start Date  Last Login Time  Salary  Bonus %  \
# 0         False   False       False            False   False    False
# 1         False   False       False            False   False    False
# 2         False   False       False            False   False    False
# 3         False   False       False            False   False    False
# 4         False   False       False            False   False    False
# ..          ...     ...         ...              ...     ...      ...
# 995       False    True       False            False   False    False
# 996       False   False       False            False   False    False
# 997       False   False       False            False   False    False
# 998       False   False       False            False   False    False
# 999       False   False       False            False   False    False
#
#      Senior Management   Team
# 0                False  False
# 1                False   True
# 2                False  False
# ...

# %%
f2.notnull()
# Out:
#      First Name  Gender  Start Date  Last Login Time  Salary  Bonus %  \
# 0          True    True        True             True    True     True
# 1          True    True        True             True    True     True
# 2          True    True        True             True    True     True
# 3          True    True        True             True    True     True
# 4          True    True        True             True    True     True
# ..          ...     ...         ...              ...     ...      ...
# 995        True   False        True             True    True     True
# 996        True    True        True             True    True     True
# 997        True    True        True             True    True     True
# 998        True    True        True             True    True     True
# 999        True    True        True             True    True     True
#
#      Senior Management   Team
# 0                 True   True
# 1                 True  False
# 2                 True   True
# ...

# %%
f2.drop_duplicates()
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
f2.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
f2[["First Name","Gender"]]
# Out:
#     First Name  Gender
# 0      Douglas    Male
# 1       Thomas    Male
# 2        Maria  Female
# 3        Jerry    Male
# 4        Larry    Male
# ..         ...     ...
# 995      Henry     NaN
# 996    Phillip    Male
# 997    Russell    Male
# 998      Larry    Male
# 999     Albert    Male
#
# [1000 rows x 2 columns]

# %%
f2.iloc[995:999]
# Out:
#     First Name Gender  Start Date Last Login Time  Salary  Bonus %  \
# 995      Henry    NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip   Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell   Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry   Male   4/20/2013         4:45 PM   60500   11.985
#
#     Senior Management                  Team
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development

# %%
f2[f2['Salary']>149000]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 160      Kathy  Female  3/18/2000         7:26 PM  149563   16.991
# 186        NaN  Female  2/23/2005         9:50 PM  149654    1.825
# 429       Rose  Female  5/28/2015         8:40 AM  149903    5.630
# 644  Katherine  Female  8/13/1996        12:21 AM  149908   18.912
# 740    Russell     NaN   5/9/2009        11:59 AM  149456    3.533
# 793     Andrea  Female  7/22/1999         9:25 AM  149105   13.707
# 828    Cynthia  Female  7/12/2006         8:55 AM  149684    7.864
#
#     Senior Management             Team
# 160              True          Finance
# 186               NaN            Sales
# 429             False  Human Resources
# 644             False          Finance
# 740             False        Marketing
# 793              True     Distribution
# 828             False          Product

# %%
f2["Salary"].sort_values().head()
# Out:
# 576    35013
# 238    35061
# 82     35095
# 63     35203
# 650    35381
# Name: Salary, dtype: int64

# %%
f2["Salary"].sort_values(ascending=False).tail()
# Out:
# 650    35381
# 63     35203
# 82     35095
# 238    35061
# 576    35013
# Name: Salary, dtype: int64

# %%
profit=(f2["Salary"]*f2["Bonus %"]/100)
f2["Gross"]=f2["Salary"]+profit
f2
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team        gross         Gross
# 0                True             Marketing   6758.04060  104066.04060
# ...

# %%
bool_series=pd.notnull(f2["Gender"])
f2[bool_series]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team        gross         Gross
# 0                True             Marketing   6758.04060  104066.04060
# ...

# %%
import numpy as np
new_data=f2.replace(to_replace=np.nan,value=101) #replace the value in nan value coloumn
new_data
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team        gross         Gross
# 0                True             Marketing   6758.04060  104066.04060
# ...

# %%
bool_series=pd.isnull(f2["Gender"])
f2[bool_series]
# Out:
#     First Name Gender  Start Date Last Login Time  Salary  Bonus %  \
# 20        Lois    NaN   4/22/1995         7:18 PM   64714    4.934
# 22      Joshua    NaN    3/8/2012         1:58 AM   90816   18.816
# 27       Scott    NaN   7/11/1991         6:58 PM  122367    5.218
# 31       Joyce    NaN   2/20/2005         2:40 PM   88657   12.752
# 41   Christine    NaN   6/28/2015         1:08 AM   66582   11.308
# ..         ...    ...         ...             ...     ...      ...
# 961    Antonio    NaN   6/18/1989         9:37 PM  103050    3.050
# 972     Victor    NaN   7/28/2006         2:49 PM   76381   11.159
# 985    Stephen    NaN   7/10/1983         8:10 PM   85668    1.909
# 989     Justin    NaN   2/10/1991         4:58 PM   38344    3.794
# 995      Henry    NaN  11/23/2014         6:09 AM  132483   16.655
#
#     Senior Management                  Team        gross         Gross
# 20               True                 Legal   3192.98876   67906.98876
# ...

# %%
f2
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team        gross         Gross
# 0                True             Marketing   6758.04060  104066.04060
# ...

# %%
f2.dropna(inplace=True) #delete in  original data file
f2
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team        gross         Gross
# 0                True             Marketing   6758.04060  104066.04060
# ...

# %%
import numpy as np

# %%
new_data=f2.replace(to_replace=np.nan,value=101) #replace the value in nan value coloumn

# %%
f3=pd.read_csv('/content/employees.csv')
f3
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
new_data=f3.replace(to_replace=np.nan,value=101) #replace the value in nan value coloumn
new_data
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     101  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   101
# ...

# %%
f3['Gender'].fillna("No Gender",inplace=True)
f3["Gender"]
# Out:
# 0           Male
# 1           Male
# 2         Female
# 3           Male
# 4           Male
#          ...
# 995    No Gender
# 996         Male
# 997         Male
# 998         Male
# 999         Male
# Name: Gender, Length: 1000, dtype: object

# %%
f3["Gender"].value_counts()
# Out:
# Female       431
# Male         424
# No Gender    145
# Name: Gender, dtype: int64

# %%
# !pip install matplotlib
import matplotlip as mp
# Out:
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-518fce382165> in <cell line: 2>()
#       1 get_ipython().system('pip install matplotlib')
# ----> 2 import matplotlip as mp
#
# ModuleNotFoundError: No module named 'matplotlip'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install matplotlib

import matplotlib as mp

# %%
# !pip show matplotlib
# Out:
# Name: matplotlib
# Version: 3.7.1
# Summary: Python plotting package
# Home-page: https://matplotlib.org
# Author: John D. Hunter, Michael Droettboom
# Author-email: matplotlib-users@python.org
# License: PSF
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: contourpy, cycler, fonttools, kiwisolver, numpy, packaging, pillow, pyparsing, python-dateutil
# Required-by: arviz, datascience, fastai, geemap, imgaug, lida, matplotlib-venn, missingno, mizani, mlxtend, music21, plotnine, prophet, pycocotools, seaborn, wordcloud, yellowbrick

# %% [markdown]
# <a href="https://colab.research.google.com/github/NIKITACHOKHARIYA/Cricknight/blob/main/mid_exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
# %matplotlib inline

# %%
data=pd.read_csv('/content/Movie-Data.csv')
data.head(5)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
data.tail(5)
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %%
data.shape
# Out:
# (1000, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
id=data.iloc[:,:4]
id.head(3)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
#
#                                          Description
# 0  A group of intergalactic criminals are forced ...
# 1  Following clues to the origin of mankind, a te...
# 2  Three girls are kidnapped by a man with a diag...

# %%
id2=data.iloc[:,-2:]
id2
# Out:
#      Revenue (Millions)  Metascore
# 0                333.13       76.0
# 1                126.46       65.0
# 2                138.12       62.0
# 3                270.32       59.0
# 4                325.02       40.0
# ..                  ...        ...
# 995                 NaN       45.0
# 996               17.54       46.0
# 997               58.01       50.0
# 998                 NaN       22.0
# 999               19.64       11.0
#
# [1000 rows x 2 columns]

# %%
id3=data.iloc[:,:3]
id3
# Out:
#      Rank                    Title                     Genre
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
# [1000 rows x 3 columns]

# %%
x=data.drop('Metascore',axis=1)
x.head(3)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
#
#                                          Description            Director  \
# 0  A group of intergalactic criminals are forced ...          James Gunn
# 1  Following clues to the origin of mankind, a te...        Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...  M. Night Shyamalan
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
#
#    Rating   Votes  Revenue (Millions)
# 0     8.1  757074              333.13
# 1     7.0  485820              126.46
# ...

# %%
y=data['Metascore']
y.head(2)
# Out:
# 0    76.0
# 1    65.0
# Name: Metascore, dtype: float64

# %%
#barplot
res=sns.barplot(x='Year',y='Rating',data=data,palette='spring')
plt.show()
# Out:
# <ipython-input-23-76889af7961e>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   res=sns.barplot(x='Year',y='Rating',data=data,palette='spring')

# %%
 res1=sns.lineplot(y='Rating',x='Year',data=data)
 plt.show()

# %%
sns.boxplot(y='Rating',x='Year',color='red',data=data)
# Out:
# <Axes: xlabel='Year', ylabel='Rating'>

# %%
res=data.groupby('Rating')
res

# %%
year=data.groupby('Year')
year

# %%
sns.barplot(y='Revenue (Millions)',x='Year',data=data,palette='mako')
# Out:
# <ipython-input-25-5941609c9c0c>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y='Revenue (Millions)',x='Year',data=data,palette='mako')
# <Axes: xlabel='Year', ylabel='Revenue (Millions)'>

# %%
sns.histplot(x='Revenue (Millions)',y='Year',data=data)
# Out:
# <Axes: xlabel='Revenue (Millions)', ylabel='Year'>

# %%
data.value_counts()
# Out:
# Rank  Title                    Genre                    Description                                                                                                                                                                               Director              Actors                                                                    Year  Runtime (Minutes)  Rating  Votes   Revenue (Millions)  Metascore
# 1     Guardians of the Galaxy  Action,Adventure,Sci-Fi  A group of intergalactic criminals are forced to work together to stop a fanatical warrior from taking control of the universe.                                                           James Gunn            Chris Pratt, Vin Diesel, Bradley Cooper, Zoe Saldana                      2014  121                8.1     757074  333.13              76.0         1
# ...

# %%
data.notnull().sum()
# Out:
# Rank                  1000
# Title                 1000
# Genre                 1000
# Description           1000
# Director              1000
# Actors                1000
# Year                  1000
# Runtime (Minutes)     1000
# Rating                1000
# Votes                 1000
# Revenue (Millions)     872
# Metascore              936
# dtype: int64

# %%
data.drop_duplicates()
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
data[data['Revenue (Millions)']>
     180].sort_values(by='Revenue (Millions)',ascending=True).head()
# Out:
#      Rank            Title                     Genre  \
# 179   180          Ant-Man   Action,Adventure,Comedy
# 101   102             Thor  Action,Adventure,Fantasy
# 333   334          Lincoln   Biography,Drama,History
# 411   412  Pitch Perfect 2              Comedy,Music
# 129   130     The Revenant  Adventure,Drama,Thriller
#
#                                            Description  \
# 179  Armed with a super-suit with the astonishing a...
# 101  The powerful but arrogant god Thor is cast out...
# 333  As the War continues to rage, America's presid...
# 411  After a humiliating command performance at The...
# 129  A frontiersman on a fur trading expedition in ...
#
#                         Director  \
# 179                  Peyton Reed
# 101              Kenneth Branagh
# 333             Steven Spielberg
# 411              Elizabeth Banks
# 129  Alejandro González Iñárritu
#
#                                                 Actors  Year  \
# ...

# %%
data['Revenue (Millions)'].value_counts()
# Out:
# Revenue (Millions)
# 0.03      7
# 0.01      5
# 0.05      4
# 0.32      4
# 0.02      4
#          ..
# 209.81    1
# 65.27     1
# 5.69      1
# 37.55     1
# 19.64     1
# Name: count, Length: 814, dtype: int64

# %%
#replace with null value
rep=data.replace(to_replace=np.nan,value=101)
rep.head(7)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
# 5     6           The Great Wall  Action,Adventure,Fantasy
# 6     7               La La Land        Comedy,Drama,Music
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
# ...

# %%
plt.barh(data['Year'],data['Revenue (Millions)'],)
plt.title('Revenue (Millions) In which year')
plt.xlabel('Year')
plt.ylabel('Revenue')
plt.show()

# %%
plt.scatter(data['Year'],data['Revenue (Millions)'],marker=4)
plt.title('Revenue (Millions) In which year')
plt.xlabel('Year')
plt.ylabel('Revenue')
plt.show()

# %%
x=data['Year'].value_counts()

plt.figure(figsize=(9, 9))
plt.pie(x,labels=x.index,autopct='%1.1f%%')

plt.show()

# %%
plt.hist(data['Year'], bins=30)
plt.show()

# %%
plt.plot(data['Year'],marker='^',linestyle='dashed')
plt.show()

# %%
plt.boxplot(data['Year'])
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
label_y=LabelEncoder()

# %%
y=label_y.fit_transform(y)

# %%
y
# Out:
# array([60, 49, 46, 43, 24, 26, 77, 55, 62, 25, 50, 58, 49, 65, 54, 45, 55,
#        42, 53, 65, 33, 80, 56, 40, 16, 84, 84, 84, 44, 20, 23, 51, 36, 49,
#        33, 59, 58, 56, 38, 84, 50, 82, 84, 50, 41, 29, 48, 84, 52,  2, 65,
#         7,  3, 52, 66, 63, 55, 35, 60, 58, 28, 49, 32, 30, 50, 42, 53, 74,
#        45, 52, 33, 44, 60,  7, 62, 34, 53, 53, 37, 44, 58, 56, 59, 63, 51,
#        43, 33, 67, 52, 35, 58, 16, 46, 41, 50, 54, 63, 46, 61, 69, 39, 41,
#        64, 84, 40, 72, 24, 28, 32, 62, 28, 80, 49, 36, 71, 26, 35, 84, 60,
#        61, 41, 32, 35, 84, 62, 61, 16, 42, 35, 60, 63, 53, 43, 72, 45, 52,
#        75, 39, 47, 28, 66, 40, 65, 70, 65, 68, 61, 40, 60, 26, 50, 52, 49,
#        66, 84, 13, 48, 52, 53, 65, 24, 47, 58, 31, 64, 40, 30, 35, 32, 44,
#        60, 68, 43, 74, 58, 44, 63, 55, 49, 48, 43, 67, 51, 84, 69, 35, 37,
#        50, 62, 59, 44, 26, 77, 32, 55, 50, 84, 57, 57, 36, 55, 31, 42, 63,
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_test,y_train=train_test_split(x,y,test_size=0.20)

# %%
x_train
# Out:
#      Rank                           Title                       Genre  \
# 449   450                          Carrie                Drama,Horror
# 13     14                           Moana  Animation,Adventure,Comedy
# 950   951  Me and Earl and the Dying Girl                Comedy,Drama
# 550   551                    The Break-Up        Comedy,Drama,Romance
# 388   389                   The Wolverine     Action,Adventure,Sci-Fi
# ..    ...                             ...                         ...
# 429   430        The Purge: Election Year        Action,Horror,Sci-Fi
# 991   992                Taare Zameen Par          Drama,Family,Music
# 927   928                The Sea of Trees                       Drama
# 257   258  Rise of the Planet of the Apes         Action,Drama,Sci-Fi
# 835   836                        The Loft    Mystery,Romance,Thriller
#
#                                            Description             Director  \
# ...

# %%
x_train.size
# Out:
# 8800

# %%
x_test.size
# Out:
# 2200

# %%
y_train.size
# Out:
# 200

# %%
y_test.size
# Out:
# 800

# %%
from sklearn.linear_model import LogisticRegression

# %%
lm=LogisticRegression()
lm.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-ce9f43b17fd1> in <cell line: 2>()
#       1 lm=LogisticRegression()
# ----> 2 lm.fit(x_train,y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1194             _dtype = [np.float64, np.float32]
#    1195
# -> 1196         X, y = self._validate_data(
#    1197             X,
#    1198             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
#     586
#
# ...

# %%
y_test
# Out:
# 449    53.0
# 13     81.0
# 950    74.0
# 550    45.0
# 388    60.0
#        ...
# 429     NaN
# 991    42.0
# 927    23.0
# 257    68.0
# 835    24.0
# Name: Metascore, Length: 800, dtype: float64
